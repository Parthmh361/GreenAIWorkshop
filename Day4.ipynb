# %%
# Out:
# Dataset URL: https://www.kaggle.com/datasets/techsash/waste-classification-data
# License(s): CC-BY-SA-4.0
# ...
#  97% 415M/427M [00:04<00:00, 104MB/s]
# 100% 427M/427M [00:04<00:00, 95.3MB/s]

# %%
# !unzip /content/drive/MyDrive/KaggleDatasets/waste-classification-data.zip -d /content/drive/MyDrive/KaggleDatasets
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/KaggleDatasets/dataset/DATASET/TRAIN/R/R_5499.jpg
#   inflating: /content/drive/MyDrive/KaggleDatasets/dataset/DATASET/TRAIN/R/R_55.jpg
#   inflating: /content/drive/MyDrive/KaggleDatasets/dataset/DATASET/TRAIN/R/R_550.jpg
#   inflating: /content/drive/MyDrive/KaggleDatasets/dataset/DATASET/TRAIN/R/R_5500.jpg
#   inflating: /content/drive/MyDrive/KaggleDatasets/dataset/DATASET/TRAIN/R/R_5501.jpg
#   inflating: /content/drive/MyDrive/KaggleDatasets/dataset/DATASET/TRAIN/R/R_5502.jpg
#   inflating: /content/drive/MyDrive/KaggleDatasets/dataset/DATASET/TRAIN/R/R_5503.jpg
#   inflating: /content/drive/MyDrive/KaggleDatasets/dataset/DATASET/TRAIN/R/R_5504.jpg
#   inflating: /content/drive/MyDrive/KaggleDatasets/dataset/DATASET/TRAIN/R/R_5505.jpg
#   inflating: /content/drive/MyDrive/KaggleDatasets/dataset/DATASET/TRAIN/R/R_5506.jpg
# ...

# %%
# !unzip /content/drive/MyDrive/KaggleDatasets/wildfire-prediction-dataset.zip -d /content/drive/MyDrive/KaggleDatasets/wildfire
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/KaggleDatasets/wildfire/valid/nowildfire/-73.465183,45.443641.jpg
#   inflating: /content/drive/MyDrive/KaggleDatasets/wildfire/valid/nowildfire/-73.465388,45.584881.jpg
#   inflating: /content/drive/MyDrive/KaggleDatasets/wildfire/valid/nowildfire/-73.469451,45.480331.jpg
#   inflating: /content/drive/MyDrive/KaggleDatasets/wildfire/valid/nowildfire/-73.471252,45.51974.jpg
#   inflating: /content/drive/MyDrive/KaggleDatasets/wildfire/valid/nowildfire/-73.472693,45.427766.jpg
#   inflating: /content/drive/MyDrive/KaggleDatasets/wildfire/valid/nowildfire/-73.473015,45.435254.jpg
#   inflating: /content/drive/MyDrive/KaggleDatasets/wildfire/valid/nowildfire/-73.475051,45.56612.jpg
#   inflating: /content/drive/MyDrive/KaggleDatasets/wildfire/valid/nowildfire/-73.477079,45.597274.jpg
#   inflating: /content/drive/MyDrive/KaggleDatasets/wildfire/valid/nowildfire/-73.478813,45.555686.jpg
# ...

# %%
import cv2
import dlib

# Load the pre-trained facial landmark predictor
predictor_path = "/content/drive/MyDrive/Colab Notebooks/Green AI/shape_predictor_68_face_landmarks.dat"
predictor = dlib.shape_predictor(predictor_path)

# Open a video capture object
cap = cv2.VideoCapture(0)

while True:
    # Read a frame from the camera
    ret, frame = cap.read()

    # Convert the frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Use Dlib to detect facial landmarks
    faces = dlib.get_frontal_face_detector()(gray)
    for face in faces:
        landmarks = predictor(gray, face)

        # Increase box size around the eyes
        left_eye = (landmarks.part(36).x - 15, landmarks.part(36).y - 15,
                    landmarks.part(39).x + 15, landmarks.part(39).y + 15)
        right_eye = (landmarks.part(42).x - 15, landmarks.part(42).y - 15,
                     landmarks.part(45).x + 15, landmarks.part(45).y + 15)

        # Draw rectangles around the eyes
        cv2.rectangle(frame, (left_eye[0], left_eye[1]), (left_eye[2], left_eye[3]), (255, 0, 0), 2)
        cv2.rectangle(frame, (right_eye[0], right_eye[1]), (right_eye[2], right_eye[3]), (255, 0, 0), 2)

    # Display the result
    cv2.imshow('Eye Tracking', frame)

    # Break the loop if the 'q' key is pressed
    key = cv2.waitKey(1)
    if key == ord('q') or key == 27:
        break

# Release the video capture object and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-f04693544791> in <cell line: 0>()
#      14
#      15     # Convert the frame to grayscale
# ---> 16     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#      17
#      18     # Use Dlib to detect facial landmarks
#
# error: OpenCV(4.10.0) /io/opencv/modules/imgproc/src/color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
# !pip install mediapipe
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 28.6 MB/s eta 0:00:00
# ...

# %%
import cv2
import mediapipe as mp
import time

# Initialize the video capture
cap = cv2.VideoCapture(0)
pTime = 0

# Initialize Mediapipe modules for face detection
mpFaceDetection = mp.solutions.face_detection
mpDraw = mp.solutions.drawing_utils
faceDetection = mpFaceDetection.FaceDetection()

while True:
    # Read a frame from the video capture
    success, img = cap.read()

    # Convert the image to RGB format (required by Mediapipe)
    imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Process the image with face detection
    results = faceDetection.process(imgRGB)
    print(results)

    # Draw bounding boxes and labels on the image if faces are detected
    if results.detections:
        for id, detection in enumerate(results.detections):
            bboxC = detection.location_data.relative_bounding_box
            ih, iw, ic = img.shape
            bbox = int(bboxC.xmin * iw), int(bboxC.ymin * ih), \
                   int(bboxC.width * iw), int(bboxC.height * ih)
            cv2.rectangle(img, bbox, (255, 0, 255), 2)
            cv2.putText(img, f'{int(detection.score[0] * 100)}%',
                        (bbox[0], bbox[1] - 20), cv2.FONT_HERSHEY_PLAIN, 3,
                        (255, 0, 0), 5)

    # Calculate and display the frames per second (FPS)
    cTime = time.time()
    fps = 1 / (cTime - pTime)
    pTime = cTime
    cv2.putText(img, f'FPS: {int(fps)}', (70, 50), cv2.FONT_HERSHEY_PLAIN, 3,
                (255, 0, 0), 3)

    # Display the image in a window named 'Image'
    cv2.imshow('Image', img)

    # Check for 'q' key press to quit the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the camera and close the window
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-6-c7c219bb72ee> in <cell line: 0>()
#      17
#      18     # Convert the image to RGB format (required by Mediapipe)
# ---> 19     imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#      20
#      21     # Process the image with face detection
#
# error: OpenCV(4.10.0) /io/opencv/modules/imgproc/src/color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
